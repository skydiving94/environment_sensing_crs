# %%
import numpy as np
import pandas as pd
import os

# %%
# Read data from GoRecDial
seeker_test_f = "./GoRecDial/dialrec-Seeker-all-test.txt"
seeker_train_f = "./GoRecDial/dialrec-Seeker-all-train.txt"
expert_test_f = "./GoRecDial/dialrec-Expert-all-test.txt"
expert_train_f = "./GoRecDial/dialrec-Expert-all-train.txt"

# %%
# Read dataset
seeker_test = open(seeker_test_f, 'r').readlines()
seeker_train = open(seeker_train_f, 'r').readlines()
expert_test = open(expert_test_f, 'r').readlines()
expert_train = open(expert_train_f, 'r').readlines()

# %%
len(expert_train), len(seeker_train)
# Out:
# (73312, 80844)

# %%
len(seeker_train)+ len(seeker_test)
# Out:
# 89644

# %%
print(seeker_train[0])
# Out:
# turn:0	text:MID33794:Batman Begins is a 2005 British-American superhero film based on the fictional DC Comics character Batman, co-written and directed by Christopher Nolan. It stars Christian Bale as Batman along with Michael Caine, Liam Neeson, Katie Holmes, Gary Oldman,and Morgan Freeman. The film reboots the "Batman" film series, telling the origin story of the character from Bruce Wayne's initial fear of bats, the death of his parents, his journey to become Batman, and his fight against Ra's al Ghul's plot to destroy Gotham City. It draws inspiration from classic comic book storylines such as "The Man Who Falls", ', and '. After a series of unsuccessful projects to resurrect Batman on screen following the 1997 critical failure of "Batman & Robin", Nolan and David S. Goyer began to work on the film in early 2003 and aimed for a darker and more realistic tone, with humanity and realism being the basis of the film. The goal was to get the audience to care for both Batman and Bruce 
# ...

# %%
print(expert_train[0])
# Out:
# turn:0	text:MID5275:Boxcar Bertha is a 1972 American film directed by Martin Scorsese. It is a loose adaptation of "Sister of the Road", an autobiographical account of Bertha Thompson written by Ben L. Reitman. It was Scorcese's secondfilm.\nMID112852:Guardians of the Galaxy is a 2014 American superhero film based on the Marvel Comics superhero team of the same name, produced by Marvel Studios and distributed by Walt Disney Studios Motion Pictures. It is the tenth installment in the Marvel CinematicUniverse. The film is directed by James Gunn, who wrote the screenplay with Nicole Perlman, and features an ensemble cast including Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel, Bradley Cooper, Lee Pace, Michael Rooker, Karen Gillan, Djimon Hounsou, John C. Reilly, Glenn Close, and Benicio del Toro. In "Guardians of the Galaxy", Peter Quill forms an uneasy alliance with a group of extraterrestrial misfits who are on the run after stealing a coveted orb. Screenwriter Nicole Perlman b
# ...

# %%
print(seeker_train[1])
# Out:
# turn:1	text:Sure. Tell me a little bit about what you like.	labels:I like comedy and romance	reward:1	label_candidates:Do you have a movie for me?|No, I don't have a preference.|You sure there's nothing else you could recommend? You've given me four recommendations so far: My Left Foot, Carlito's Way, Immortal Beloved, and Four Weddings and a Funeral. Anything else come to mind as a potential recommendation for someone who likes movies, particularly dramas, crime thrillers, and historically movies?|I don't like war films.|This is a great movie and of course good acting by Edward Norton and Brad Pitt.|i enjoy drama, action, and war films|That also sounds like a great choice, it is also a fun and family orientated movie. Do you know any movies that are based on a novel or an action thriller? |It looks like such a funny movie with comedy, a fun plot, and some adult hilarity to it.|I have never seen this one|That does sound like something I'd like!|I like comedy and romance|That could wo
# ...

# %%
print(expert_train[1])
# Out:
# turn:1	text:I like comedy and romance	labels:OK. Do you have any interest in sci fi?	reward:1	label_candidates:Hello there. I most certainly can and will do so. |It is a timeless classic and he likes drama.|If you had to lean more towards comedy or thrillers, what are you feeling like at the moment?|It has Tom hanks and is a comedy.|Hm, all I have left are Dramas. Lets try this|RECOMMEND MID59935|He likes comedy as well as drama.|I think historical drama would make seeker love it|RECOMMEND MID4463|war film for some reason this is the answer i guess haha nice stufff|It's a Woody Allen movie|This movie is also Science Fiction plus funny too |Not really, do you like Sci-Fi?|Apparently it was wrong, sorry. I think you'll like my next recommendation though.|Would foreign comedy work or would you prefer drama only? |Sounds great!|RECOMMEND MID91079|I have a sci fi thriller from 2013 and a supernatural fantasy drama from 2001, other than that I have american drama, animated russian fil or a
# ...
